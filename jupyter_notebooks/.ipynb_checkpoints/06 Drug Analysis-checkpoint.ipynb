# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import itertools as it
from glob import glob
from matplotlib import pyplot as plt
from pymea import plotting
from pymea import matlab_compatibility as mc

# %%
data_path = '/home/sean/mea data/06/06_spk_freq_table_bin60.csv'
data_table = pd.read_csv(data_path)
time_vector = data_table['time'].map(mc.datetime_str_to_datetime)

# %%
condition_cols = {
    'NaCl': 1,
    'DTX_10nM': 2,
    'DTX_100nM': 3,
    'PTX_0.5uM': 4,
    'Control': 5,
    'Ba_0.1mM': 6,
    'KCl_0.1mM': 7,
    'DMSO': 8,
}

def create_well_assignment_filter(cond_name):
    def well_assignment_filter(unit_name):
        col = mc.get_col_number(unit_name)
        return col == condition_cols[cond_name]
    return well_assignment_filter

well_filter_dict = {cond_name: create_well_assignment_filter(cond_name) for cond_name in condition_cols.iterkeys()}

# %%
cat_table = plotting.construct_categorized_dataframe(data_table, well_filter_dict)
cat_table['spike_freq'] = cat_table['spike_freq']/60 # convert from spikes/1 minute to spikes/second
cat_table['spike_freq'] = plotting.smooth(cat_table['spike_freq'], kernel_size=20) # smooth using a 20 minute kernel

# %%
# get rid of times at beginning and end of each 1 hr recording
cat_table = cat_table.query('''(time > "2017-08-31 18:16:00" & time < "2017-08-31 19:16:00") \
                       | (time > "2017-08-31 20:16:00" & time < "2017-08-31 21:16:00") \
                       | (time > "2017-08-31 22:16:00" & time < "2017-08-31 23:16:00") \
                       | (time > "2017-09-01 00:16:00" & time < "2017-09-01 01:16:00") \
                       | (time > "2017-09-01 02:16:00" & time < "2017-09-01 03:16:00") \
                       | (time > "2017-09-01 04:16:00" & time < "2017-09-01 05:16:00") \
                       | (time > "2017-09-01 06:16:00" & time < "2017-09-01 07:16:00") \
                       | (time > "2017-09-01 08:16:00" & time < "2017-09-01 09:16:00") \
                       | (time > "2017-09-01 10:16:00" & time < "2017-09-01 11:16:00") \
                       | (time > "2017-09-01 12:16:00" & time < "2017-09-01 13:16:00") \
                       | (time > "2017-09-01 14:16:00" & time < "2017-09-01 15:16:00") \
                       | (time > "2017-09-01 15:41:00")''')
cat_table_big = cat_table.query('spike_freq > 1')
cat_table_small = cat_table.query('spike_freq < 1')

# %%
#baseline between 2017-08-31 18:16:00 and 2017-09-01 15:16:00

baseline_table = cat_table.query('time > "2017-08-31 18:16:00"').query('time < "2017-09-01 15:16:00"')
stim_table = cat_table.query('time > "2017-09-01 15:16:00"')

# %%
plt.figure(figsize=(10,7))
plotting.plot_mean_frequency_traces(cat_table_big)

# %%
plt.figure(figsize=(10,7))
plotting.plot_unit_traces(cat_table)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-112-515c91c7e953> in <module>()
#       1 plt.figure(figsize=(10,7))
# ----> 2 plotting.plot_unit_traces(cat_table)
#
# /home/sean/mea_analysis/jupyter_notebooks/pymea/plotting.py in plot_unit_traces(category_dataframe, **plot_kwargs)
#      35     """
#      36     for unit in category_dataframe['unit_name'].unique():
# ---> 37         unit_table = category_dataframe.query('unit_name == @unit')
#      38         plt.plot(unit_table['time'], unit_table['spike_freq'], **plot_kwargs)
#      39
#
# /home/sean/anaconda3/envs/ipykernel_py2/lib/python2.7/site-packages/pandas/core/frame.pyc in query(self, expr, inplace, **kwargs)
#    2114         kwargs['level'] = kwargs.pop('level', 0) + 1
#    2115         kwargs['target'] = None
# -> 2116         res = self.eval(expr, **kwargs)
#    2117
#    2118         try:
#
# /home/sean/anaconda3/envs/ipykernel_py2/lib/python2.7/site-packages/pandas/core/frame.pyc in eval(self, expr, inplace, **kwargs)
#    2184             kwargs['target'] = self
#    2185         kwargs['resolvers'] = kwargs.get('resolvers', ()) + tuple(resolvers)
# -> 2186         return _eval(expr, inplace=inplace, **kwargs)
#    2187
#    2188     def select_dtypes(self, include=None, exclude=None):
#
# /home/sean/anaconda3/envs/ipykernel_py2/lib/python2.7/site-packages/pandas/core/computation/eval.pyc in eval(expr, parser, engine, truediv, local_dict, global_dict, resolvers, level, target, inplace)
#     260
#     261         parsed_expr = Expr(expr, engine=engine, parser=parser, env=env,
# --> 262                            truediv=truediv)
#     263
#     264         # construct the engine and evaluate the parsed expression
#
# /home/sean/anaconda3/envs/ipykernel_py2/lib/python2.7/site-packages/pandas/core/computation/expr.pyc in __init__(self, expr, engine, parser, env, truediv, level)
#     725         self.env.scope['truediv'] = truediv
#     726         self._visitor = _parsers[parser](self.env, self.engine, self.parser)
# --> 727         self.terms = self.parse()
#     728
#     729     @property
#
# /home/sean/anaconda3/envs/ipykernel_py2/lib/python2.7/site-packages/pandas/core/computation/expr.pyc in parse(self)
#     742     def parse(self):
#     743         """Parse an expression"""
# --> 744         return self._visitor.visit(self.expr)
#     745
#     746     @property
#
# /home/sean/anaconda3/envs/ipykernel_py2/lib/python2.7/site-packages/pandas/core/computation/expr.pyc in visit(self, node, **kwargs)
#     311         method = 'visit_' + node.__class__.__name__
#     312         visitor = getattr(self, method)
# --> 313         return visitor(node, **kwargs)
#     314
#     315     def visit_Module(self, node, **kwargs):
#
# /home/sean/anaconda3/envs/ipykernel_py2/lib/python2.7/site-packages/pandas/core/computation/expr.pyc in visit_Module(self, node, **kwargs)
#     317             raise SyntaxError('only a single expression is allowed')
#     318         expr = node.body[0]
# --> 319         return self.visit(expr, **kwargs)
#     320
#     321     def visit_Expr(self, node, **kwargs):
#
# /home/sean/anaconda3/envs/ipykernel_py2/lib/python2.7/site-packages/pandas/core/computation/expr.pyc in visit(self, node, **kwargs)
#     311         method = 'visit_' + node.__class__.__name__
#     312         visitor = getattr(self, method)
# --> 313         return visitor(node, **kwargs)
#     314
#     315     def visit_Module(self, node, **kwargs):
#
# /home/sean/anaconda3/envs/ipykernel_py2/lib/python2.7/site-packages/pandas/core/computation/expr.pyc in visit_Expr(self, node, **kwargs)
#     320
#     321     def visit_Expr(self, node, **kwargs):
# --> 322         return self.visit(node.value, **kwargs)
#     323
#     324     def _rewrite_membership_op(self, node, left, right):
#
# /home/sean/anaconda3/envs/ipykernel_py2/lib/python2.7/site-packages/pandas/core/computation/expr.pyc in visit(self, node, **kwargs)
#     311         method = 'visit_' + node.__class__.__name__
#     312         visitor = getattr(self, method)
# --> 313         return visitor(node, **kwargs)
#     314
#     315     def visit_Module(self, node, **kwargs):
#
# /home/sean/anaconda3/envs/ipykernel_py2/lib/python2.7/site-packages/pandas/core/computation/expr.pyc in visit_Compare(self, node, **kwargs)
#     642             op = self.translate_In(ops[0])
#     643             binop = ast.BinOp(op=op, left=node.left, right=comps[0])
# --> 644             return self.visit(binop)
#     645
#     646         # recursive case: we have a chained comparison, a CMP b CMP c, etc.
#
# /home/sean/anaconda3/envs/ipykernel_py2/lib/python2.7/site-packages/pandas/core/computation/expr.pyc in visit(self, node, **kwargs)
#     311         method = 'visit_' + node.__class__.__name__
#     312         visitor = getattr(self, method)
# --> 313         return visitor(node, **kwargs)
#     314
#     315     def visit_Module(self, node, **kwargs):
#
# /home/sean/anaconda3/envs/ipykernel_py2/lib/python2.7/site-packages/pandas/core/computation/expr.pyc in visit_BinOp(self, node, **kwargs)
#     416         op, op_class, left, right = self._maybe_transform_eq_ne(node)
#     417         left, right = self._maybe_downcast_constants(left, right)
# --> 418         return self._maybe_evaluate_binop(op, op_class, left, right)
#     419
#     420     def visit_Div(self, node, **kwargs):
#
# /home/sean/anaconda3/envs/ipykernel_py2/lib/python2.7/site-packages/pandas/core/computation/expr.pyc in _maybe_evaluate_binop(self, op, op_class, lhs, rhs, eval_in_python, maybe_eval_in_python)
#     403         if res.op in eval_in_python:
#     404             # "in"/"not in" ops are always evaluated in python
# --> 405             return self._maybe_eval(res, eval_in_python)
#     406         elif self.engine != 'pytables':
#     407             if (getattr(lhs, 'return_type', None) == object or
#
# /home/sean/anaconda3/envs/ipykernel_py2/lib/python2.7/site-packages/pandas/core/computation/expr.pyc in _maybe_eval(self, binop, eval_in_python)
#     380         # call will be evaluated using isin (in python space)
#     381         return binop.evaluate(self.env, self.engine, self.parser,
# --> 382                               self.term_type, eval_in_python)
#     383
#     384     def _maybe_evaluate_binop(self, op, op_class, lhs, rhs,
#
# /home/sean/anaconda3/envs/ipykernel_py2/lib/python2.7/site-packages/pandas/core/computation/ops.pyc in evaluate(self, env, engine, parser, term_type, eval_in_python)
#     380         """
#     381         if engine == 'python':
# --> 382             res = self(env)
#     383         else:
#     384             # recurse over the left/right nodes
#
# /home/sean/anaconda3/envs/ipykernel_py2/lib/python2.7/site-packages/pandas/core/computation/ops.pyc in __call__(self, env)
#     361         right = self.rhs(env)
#     362
# --> 363         return self.func(left, right)
#     364
#     365     def evaluate(self, env, engine, parser, term_type, eval_in_python):
#
# /home/sean/anaconda3/envs/ipykernel_py2/lib/python2.7/site-packages/pandas/core/computation/ops.pyc in _in(x, y)
#     233     """
#     234     try:
# --> 235         return x.isin(y)
#     236     except AttributeError:
#     237         if is_list_like(x):
#
# /home/sean/anaconda3/envs/ipykernel_py2/lib/python2.7/site-packages/pandas/core/series.pyc in isin(self, values)
#    2553
#    2554         """
# -> 2555         result = algorithms.isin(_values_from_object(self), values)
#    2556         return self._constructor(result, index=self.index).__finalize__(self)
#    2557
#
# /home/sean/anaconda3/envs/ipykernel_py2/lib/python2.7/site-packages/pandas/core/algorithms.pyc in isin(comps, values)
#     424             comps = comps.astype(object)
#     425
# --> 426     return f(comps, values)
#     427
#     428
#
# /home/sean/anaconda3/envs/ipykernel_py2/lib/python2.7/site-packages/pandas/core/algorithms.pyc in <lambda>(x, y)
#     404     f = lambda x, y: htable.ismember_object(x, values)
#     405     if (_np_version_under1p8 and compat.PY3) or len(comps) > 1000000:
# --> 406         f = lambda x, y: np.in1d(x, y)
#     407     elif is_integer_dtype(comps):
#     408         try:
#
# /home/sean/anaconda3/envs/ipykernel_py2/lib/python2.7/site-packages/numpy/lib/arraysetops.pyc in in1d(ar1, ar2, assume_unique, invert)
#     461             mask = np.zeros(len(ar1), dtype=np.bool)
#     462             for a in ar2:
# --> 463                 mask |= (ar1 == a)
#     464         return mask
#     465
#
# KeyboardInterrupt:

# %%
plotting.foldInductionPlusMean(cat_table, baseline_table, stim_table, "DTX_100nM", 'DTX 100nM', minHz = 0.01)
# Out:
# pymea/plotting.py:390: RuntimeWarning: invalid value encountered in double_scalars
#   varOfBaseline = (max(unit_b['spike_freq'])-min(unit_b['spike_freq']))/meanOfBaseline

# %%
plotting.foldInductionPlusMean(cat_table, baseline_table, stim_table, "DTX_10nM", 'DTX 10nM', minHz = 0.01)

# %%
plotting.foldInductionPlusMean(cat_table, baseline_table, stim_table, "Ba_0.1mM", 'Ba_0.1mM', var=2.5, minHz = 0.01)

# %%
plotting.foldInductionPlusMean(cat_table, baseline_table, stim_table, "PTX_0.5uM", 'PTX_0.5uM', var=2.5, minHz = 0.01)

# %%
plotting.foldInductionPlusMean(cat_table, baseline_table, stim_table, "KCl_0.1mM", 'KCl_0.1mM', minHz = 0.01)

# %%
plotting.foldInductionPlusMean(cat_table, baseline_table, stim_table, "NaCl", 'NaCl', minHz = 0.01)

# %%
plt.figure(figsize=(10,7))
plotting.foldInductionPlusMean(cat_table.query('time < "2017-09-02"'), baseline_table, stim_table.query('time < "2017-09-02"'), "Control", 'Control', ind_filter = False, var = 2.5, minHz = 0.01)
# Out:
# pymea/plotting.py:429: RuntimeWarning: invalid value encountered in double_scalars
#   varOfBaseline = (max(unit_b['spike_freq'])-min(unit_b['spike_freq']))/meanOfBaseline

# %%
plt.figure(figsize=(10,7))
plotting.foldInductionPlusMean(cat_table, baseline_table, stim_table, "Control", 'Control', ind_filter = False, var = 2.5, minHz = 0.01, maxHz = 10000)

# %%
plotting.foldInductionPlusMean(cat_table, baseline_table, stim_table, "DMSO", 'DMSO', ind_filter = False, minHz = 0.01)
