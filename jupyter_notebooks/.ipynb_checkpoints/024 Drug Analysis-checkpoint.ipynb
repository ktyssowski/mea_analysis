# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import itertools as it
from glob import glob
from matplotlib import pyplot as plt
from pymea import plotting
from pymea import matlab_compatibility as mc

# %%
data_path = '/home/sean/mea data/024/024_spk_freq_table_bin60.csv'
data_table = pd.read_csv(data_path)
time_vector = data_table['time'].map(mc.datetime_str_to_datetime)

# %%
condition_cols = {
    'DMSO': 1,
    'PTX_0.5uM': 2,
    'DTX_10nM': 3,
    'DTX_100nM': 4,
    'Control': 5,
    'Ba_0.1mM': 6,
    'KCl_0.1mM': 7,
    'NaCl_60mM': 8,
    'ReaChR': 9
}

def create_well_assignment_filter(cond_name):
    def well_assignment_filter(unit_name):
        col = mc.get_col_number(unit_name)
        row = mc.get_row_number(unit_name)
        if cond_name == 'ReaChR':
            if row <= 2:
                return True
            else:
                return False
        elif row <= 2:
            return False
        else:
            return col == condition_cols[cond_name]
    return well_assignment_filter

well_filter_dict = {cond_name: create_well_assignment_filter(cond_name) for cond_name in condition_cols.iterkeys()}

# %%
cat_table = plotting.construct_categorized_dataframe(data_table, well_filter_dict)
cat_table['spike_freq'] = cat_table['spike_freq']/60 # convert from spikes/1 minute to spikes/second

# %%
plt.figure(figsize=(10,7))
plotting.plot_mean_frequency_traces(cat_table)

# %%
cat_table = cat_table.query('time > "2017-06-29 19:05:00"') #get rid of times before start of baseline recording
# get rid of times at beginning and end of each 1 hr recording
cat_table = cat_table.query('''(time > "2017-06-29 19:10:00" & time < "2017-06-29 19:45:00") \
                       | (time > "2017-06-29 22:10:00" & time < "2017-06-29 22:45:00") \
                       | (time > "2017-06-30 01:10:00" & time < "2017-06-30 01:45:00")  \
                       | (time > "2017-06-30 04:10:00" & time < "2017-06-30 04:45:00") \
                       | (time > "2017-06-30 07:10:00" & time < "2017-06-30 07:45:00") \
                       | (time > "2017-06-30 10:10:00" & time < "2017-06-30 10:45:00") \
                       | (time > "2017-06-30 13:10:00" & time < "2017-06-30 13:45:00") \
                       | (time > "2017-06-30 16:10:00" & time < "2017-06-30 16:45:00") \
                       | (time > "2017-06-30 18:46:00")''')
cat_table['spike_freq'] = plotting.smooth(cat_table['spike_freq'], kernel_size=20) # smooth using a 20 minute kernel

# %%
plt.figure(figsize=(10,7))
plotting.plot_mean_frequency_traces(test)

# %%
#baseline between 2017-06-29 19:05:00 and 2017-06-30 18:46:00

baseline_table = cat_table.query('time > "2017-06-29 19:05:00"').query('time < "2017-06-30 18:46:00"')
stim_table = cat_table.query('time > "2017-06-30 18:46:00"')

# %%
plotting.foldInductionPlusMean(cat_table, baseline_table, stim_table, "DTX_100nM", 'DTX 100nM')

# %%
plotting.foldInductionPlusMean(cat_table, baseline_table, stim_table, "DTX_10nM", 'DTX 10nM')

# %%
plotting.foldInductionPlusMean(cat_table, baseline_table, stim_table, "Ba_0.1mM", 'Ba_0.1mM', var=2.5)

# %%
plotting.foldInductionPlusMean(cat_table, baseline_table, stim_table, "PTX_0.5uM", 'PTX_0.5uM', var=2.5)

# %%
plotting.foldInductionPlusMean(cat_table, baseline_table, stim_table, "KCl_0.1mM", 'KCl_0.1mM')

# %%
plotting.foldInductionPlusMean(cat_table, baseline_table, stim_table, "NaCl_60mM", 'NaCl_60mM')
# Out:
# pymea/plotting.py:151: RuntimeWarning: invalid value encountered in double_scalars
#   varOfBaseline = (max(unit_b['spike_freq'])-min(unit_b['spike_freq']))/meanOfBaseline
# nan
# 2.5
# nan
# 2.5
# nan
# 2.5
# nan
# 2.5
# nan
# 2.5
# nan
# 2.5
# nan
# 2.5
# nan
# 2.5
# nan
# 2.5
# nan
# 2.5
# nan
# 2.5
# nan
# 2.5
# nan
# 2.5
# nan
# 2.5
# nan
# 2.5
# nan
# 2.5
# nan
# 2.5
# nan
# 2.5
# 14.0
# 2.5
# nan
# 2.5
# nan
# 2.5
# nan
# 2.5
# nan
# 2.5
# nan
# 2.5
# nan
# 2.5
# nan
# 2.5
# nan
# 2.5
# nan
# 2.5
# nan
# 2.5
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-94-764a400c99df> in <module>()
# ----> 1 plotting.foldInductionPlusMean(cat_table, baseline_table, stim_table, "NaCl_60mM", 'NaCl_60mM')
#
# /home/sean/mea_analysis/jupyter_notebooks/pymea/plotting.py in foldInductionPlusMean(cat_table, baseline_table, stim_table, condition, title, var, minHz, ind_filter)
#     220
#     221     if ind_filter:
# --> 222         foldInductionPlusMean_stim(cat_table, baseline_table, stim_table, condition, title, var=2.5, minHz=0.01)
#     223     else:
#     224         foldInductionPlusMean_ctrl(cat_table, baseline_table, stim_table, condition, title, var=2.5, minHz=0.01)
#
# /home/sean/mea_analysis/jupyter_notebooks/pymea/plotting.py in foldInductionPlusMean_stim(cat_table, baseline_table, stim_table, condition, title, var, minHz)
#     164     plt.ylim(0,10)
#     165     plt.axhline(y=1, xmin=0, xmax=1, hold=None, color='black')
# --> 166     mean_freq_traces = c_filter.groupby(('condition', 'time'))['spike_freq'].mean()
#     167     mean_freq_traces = mean_freq_traces.rename('spike frequency').reset_index() # Convert the multiindexed series back to a dataframe
#     168     mean_freq_traces_b = b_filter.groupby(('condition', 'time'))['spike_freq'].mean()
#
# /home/sean/anaconda3/envs/ipykernel_py2/lib/python2.7/site-packages/pandas/core/generic.pyc in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, **kwargs)
#    4414         return groupby(self, by=by, axis=axis, level=level, as_index=as_index,
#    4415                        sort=sort, group_keys=group_keys, squeeze=squeeze,
# -> 4416                        **kwargs)
#    4417
#    4418     def asfreq(self, freq, method=None, how=None, normalize=False,
#
# /home/sean/anaconda3/envs/ipykernel_py2/lib/python2.7/site-packages/pandas/core/groupby.pyc in groupby(obj, by, **kwds)
#    1697         raise TypeError('invalid type: %s' % type(obj))
#    1698
# -> 1699     return klass(obj, by, **kwds)
#    1700
#    1701
#
# /home/sean/anaconda3/envs/ipykernel_py2/lib/python2.7/site-packages/pandas/core/groupby.pyc in __init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, squeeze, **kwargs)
#     390                                                     level=level,
#     391                                                     sort=sort,
# --> 392                                                     mutated=self.mutated)
#     393
#     394         self.obj = obj
#
# /home/sean/anaconda3/envs/ipykernel_py2/lib/python2.7/site-packages/pandas/core/groupby.pyc in _get_grouper(obj, key, axis, level, sort, mutated)
#    2688                 in_axis, name, level, gpr = False, None, gpr, None
#    2689             else:
# -> 2690                 raise KeyError(gpr)
#    2691         elif isinstance(gpr, Grouper) and gpr.key is not None:
#    2692             # Add key to exclusions
#
# KeyError: 'condition'

# %%
plotting.foldInductionPlusMean(cat_table, baseline_table, stim_table, "Ctrl", 'Ctrl', ind_filter = False)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-95-d6d9ea67cd35> in <module>()
# ----> 1 plotting.foldInductionPlusMean(cat_table, baseline_table, stim_table, "Ctrl", 'Ctrl', ind_filter = False)
#
# /home/sean/mea_analysis/jupyter_notebooks/pymea/plotting.py in foldInductionPlusMean(cat_table, baseline_table, stim_table, condition, title, var, minHz, ind_filter)
#     221         foldInductionPlusMean_stim(cat_table, baseline_table, stim_table, condition, title, var=2.5, minHz=0.01)
#     222     else:
# --> 223         foldInductionPlusMean_ctrl(cat_table, baseline_table, stim_table, condition, title, var=2.5, minHz=0.01)
#     224
#     225
#
# /home/sean/mea_analysis/jupyter_notebooks/pymea/plotting.py in foldInductionPlusMean_ctrl(cat_table, baseline_table, stim_table, condition, title, var, minHz)
#     202     plt.ylim(0,10)
#     203     plt.axhline(y=1, xmin=0, xmax=1, hold=None, color='black')
# --> 204     mean_freq_traces = c_filter.groupby(('condition', 'time'))['spike_freq'].mean()
#     205     mean_freq_traces = mean_freq_traces.rename('spike frequency').reset_index() # Convert the multiindexed series back to a dataframe
#     206     mean_freq_traces_b = b_filter.groupby(('condition', 'time'))['spike_freq'].mean()
#
# /home/sean/anaconda3/envs/ipykernel_py2/lib/python2.7/site-packages/pandas/core/generic.pyc in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, **kwargs)
#    4414         return groupby(self, by=by, axis=axis, level=level, as_index=as_index,
#    4415                        sort=sort, group_keys=group_keys, squeeze=squeeze,
# -> 4416                        **kwargs)
#    4417
#    4418     def asfreq(self, freq, method=None, how=None, normalize=False,
#
# /home/sean/anaconda3/envs/ipykernel_py2/lib/python2.7/site-packages/pandas/core/groupby.pyc in groupby(obj, by, **kwds)
#    1697         raise TypeError('invalid type: %s' % type(obj))
#    1698
# -> 1699     return klass(obj, by, **kwds)
#    1700
#    1701
#
# /home/sean/anaconda3/envs/ipykernel_py2/lib/python2.7/site-packages/pandas/core/groupby.pyc in __init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, squeeze, **kwargs)
#     390                                                     level=level,
#     391                                                     sort=sort,
# --> 392                                                     mutated=self.mutated)
#     393
#     394         self.obj = obj
#
# /home/sean/anaconda3/envs/ipykernel_py2/lib/python2.7/site-packages/pandas/core/groupby.pyc in _get_grouper(obj, key, axis, level, sort, mutated)
#    2688                 in_axis, name, level, gpr = False, None, gpr, None
#    2689             else:
# -> 2690                 raise KeyError(gpr)
#    2691         elif isinstance(gpr, Grouper) and gpr.key is not None:
#    2692             # Add key to exclusions
#
# KeyError: 'condition'

# %%
plotting.foldInductionPlusMean(cat_table, baseline_table, stim_table, "DMSO", 'DMSO', ind_filter = False)
# Out:
# pymea/plotting.py:192: RuntimeWarning: invalid value encountered in double_scalars
#   varOfBaseline = (max(unit_b['spike_freq'])-min(unit_b['spike_freq']))/meanOfBaseline

# %%
plotting.foldInductionPlusMean(cat_table, baseline_table, stim_table, "ReaChR", 'ReaChR', ind_filter = False)
